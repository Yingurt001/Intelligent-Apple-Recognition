# %%
import cv2
import numpy as np
import glob
from PIL import Image

# 读取图像
image_paths = glob.glob('Attachment 1/2.jpg')  # 修改为你的图像文件夹路径

for image_path in image_paths:
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)
    cv2.imshow("apples", apples)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    # lower_red1 = np.array([0, 100, 100])
    # upper_red1 = np.array([10, 255, 255])
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    # lower_red2 = np.array([160, 100, 100])
    # upper_red2 = np.array([180, 255, 255])
    # 青苹果
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])


    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    # 青苹果开关
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    # Image.fromarray(mask).show()
    cv2.imshow("mask", mask)

    # 灰度
    # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # Image.fromarray(mask).show()

    # 高斯模糊
    mask = cv2.GaussianBlur(mask,(5,5),0)
    # Image.fromarray(mask).show()
    cv2.imshow("GaussianBlur", mask)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((7, 7), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)
    # Image.fromarray(mask).show()
    cv2.imshow("erode & dilate", mask)

    # 寻找轮廓
    # contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        # 中心点 x+1/2*w，y+1/2*h
    str = 'the number of apples: ' + str(len(contours))
    # img = cv2.putText(draw_img, str, (0, 10), cv2.FONT_HERSHEY_TRIPLEX, 0.2, (0, 0, 255), 1)
    print("contours 数量：", len(contours))

    cv2.imshow("img", image)
    cv2.imshow("draw_img", draw_img)
    cv2.waitKey(0)
cv2.destroyAllWindows()
print(1+1)
# Out:
# 2

# %%
import cv2
import numpy as np
import glob
from PIL import Image

# 读取图像
image_paths = glob.glob('Attachment_1/2.jpg')  # 修改为你的图像文件夹路径

for image_path in image_paths:
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)
    cv2.imshow("apples", apples)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    # lower_red1 = np.array([0, 100, 100])
    # upper_red1 = np.array([10, 255, 255])
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    # lower_red2 = np.array([160, 100, 100])
    # upper_red2 = np.array([180, 255, 255])
    # 青苹果
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])


    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    # 青苹果开关
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    # Image.fromarray(mask).show()
    cv2.imshow("mask", mask)

    # 灰度
    # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # Image.fromarray(mask).show()

    # 高斯模糊
    mask = cv2.GaussianBlur(mask,(5,5),0)
    # Image.fromarray(mask).show()
    cv2.imshow("GaussianBlur", mask)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((7, 7), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)
    # Image.fromarray(mask).show()
    cv2.imshow("erode & dilate", mask)

    # 寻找轮廓
    # contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        # 中心点 x+1/2*w，y+1/2*h
    str = 'the number of apples: ' + str(len(contours))
    # img = cv2.putText(draw_img, str, (0, 10), cv2.FONT_HERSHEY_TRIPLEX, 0.2, (0, 0, 255), 1)
    print("contours 数量：", len(contours))

    cv2.imshow("img", image)
    cv2.imshow("draw_img", draw_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

def process_image(image_path, output_folder):
    image = cv2.imread(image_path)

    # 以下是图像处理的代码...

    # 保存中间和最终图像
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存苹果图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_apples.jpg"), apples)

    # 保存掩膜图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_mask.jpg"), mask)

    # 保存高斯模糊图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_GaussianBlur.jpg"), mask)

    # 保存腐蚀和膨胀图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_erode_dilate.jpg"), mask)

    # 保存绘制轮廓后的图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")

# 读取图像
image_paths = glob.glob('Attachment_1/*.jpg')  # 修改为你的图像文件夹路径

for image_path in image_paths:
    process_image(image_path, output_folder)

# %%
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

def process_image(image_path, output_folder):
    # 读取图像
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])

    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    # 高斯模糊
    mask = cv2.GaussianBlur(mask, (5, 5), 0)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((7, 7), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    # 寻找轮廓
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    # 绘制轮廓和边界框
    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # 生成图像名称
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存处理后的各阶段图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_apples.jpg"), apples)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_mask.jpg"), mask)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_GaussianBlur.jpg"), mask)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_erode_dilate.jpg"), mask)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")
    return
# 读取图像
image_paths = glob.glob('Attachment 1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folder)

# %%
#上面的代码跑不出来现在重新试一试
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "WhatdoIwant?"
os.makedirs(output_folder, exist_ok=True)

def process_image(image_path, output_folder):
    # 读取图像
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])

    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    # 高斯模糊
    mask_blur = cv2.GaussianBlur(mask, (5, 5), 0)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((7, 7), np.uint8)
    mask_final = cv2.erode(mask_blur, kernel, iterations=2)
    mask_final = cv2.dilate(mask_final, kernel, iterations=2)

    # 寻找轮廓
    contours, _ = cv2.findContours(mask_final, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    # 绘制轮廓和边界框
    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # 生成图像名称
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存处理后的各阶段图像
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_apples.jpg"), apples)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_mask.jpg"), mask_final)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_GaussianBlur.jpg"), mask_blur)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_erode_dilate.jpg"), mask_final)
    cv2.imwrite(os.path.join(output_folder, f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")
    return

# 读取图像
image_paths = glob.glob('Attachment 1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folder)

# %%
import cv2
import numpy as np
import glob
import os
# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

# 创建不同处理阶段的文件夹
output_folders = {
    'apples': os.path.join(output_folder, 'apples'),
    'mask': os.path.join(output_folder, 'mask'),
    'GaussianBlur': os.path.join(output_folder, 'GaussianBlur'),
    'erode_dilate': os.path.join(output_folder, 'erode_dilate'),
    'draw_img': os.path.join(output_folder, 'draw_img')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

def process_image(image_path, output_folders):
    # 读取图像
    image = cv2.imread(image_path)

    # 以下是图像处理的代码...

    # 保存中间和最终图像
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存苹果图像
    cv2.imwrite(os.path.join(output_folders['apples'], f"{image_name}_apples.jpg"), apples)

    # 保存掩膜图像
    cv2.imwrite(os.path.join(output_folders['mask'], f"{image_name}_mask.jpg"), mask)

    # 保存高斯模糊图像
    cv2.imwrite(os.path.join(output_folders['GaussianBlur'], f"{image_name}_GaussianBlur.jpg"), mask)

    # 保存腐蚀和膨胀图像
    cv2.imwrite(os.path.join(output_folders['erode_dilate'], f"{image_name}_erode_dilate.jpg"), mask)

    # 保存绘制轮廓后的图像
    cv2.imwrite(os.path.join(output_folders['draw_img'], f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")

# 读取图像
image_paths = glob.glob('Attachment_1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folders)

# %%
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

# 创建不同处理阶段的文件夹
output_folders = {
    'apples': os.path.join(output_folder, 'apples'),
    'mask': os.path.join(output_folder, 'mask'),
    'GaussianBlur': os.path.join(output_folder, 'GaussianBlur'),
    'erode_dilate': os.path.join(output_folder, 'erode_dilate'),
    'draw_img': os.path.join(output_folder, 'draw_img')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

def process_image(image_path, output_folders):
    # 读取图像
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    # 以下是图像处理的代码...

    # 保存中间和最终图像
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存苹果图像
    cv2.imwrite(os.path.join(output_folders['apples'], f"{image_name}_apples.jpg"), apples)

    # 保存掩膜图像
    cv2.imwrite(os.path.join(output_folders['mask'], f"{image_name}_mask.jpg"), mask)

    # 保存高斯模糊图像
    cv2.imwrite(os.path.join(output_folders['GaussianBlur'], f"{image_name}_GaussianBlur.jpg"), mask)

    # 保存腐蚀和膨胀图像
    cv2.imwrite(os.path.join(output_folders['erode_dilate'], f"{image_name}_erode_dilate.jpg"), mask)

    # 保存绘制轮廓后的图像
    cv2.imwrite(os.path.join(output_folders['draw_img'], f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")

# 读取图像
image_paths = glob.glob('Attachment_1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folders)

# %%
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

# 创建不同处理阶段的文件夹
output_folders = {
    'apples': os.path.join(output_folder, 'apples'),
    'mask': os.path.join(output_folder, 'mask'),
    'GaussianBlur': os.path.join(output_folder, 'GaussianBlur'),
    'erode_dilate': os.path.join(output_folder, 'erode_dilate'),
    'draw_img': os.path.join(output_folder, 'draw_img')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

def process_image(image_path, output_folders):
    # 读取图像
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])

    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    # 以下是图像处理的代码...

    # 保存中间和最终图像
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存苹果图像
    cv2.imwrite(os.path.join(output_folders['apples'], f"{image_name}_apples.jpg"), apples)

    # 保存掩膜图像
    cv2.imwrite(os.path.join(output_folders['mask'], f"{image_name}_mask.jpg"), mask)

    # 保存高斯模糊图像
    cv2.imwrite(os.path.join(output_folders['GaussianBlur'], f"{image_name}_GaussianBlur.jpg"), mask)

    # 保存腐蚀和膨胀图像
    cv2.imwrite(os.path.join(output_folders['erode_dilate'], f"{image_name}_erode_dilate.jpg"), mask)

    # 保存绘制轮廓后的图像
    cv2.imwrite(os.path.join(output_folders['draw_img'], f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")

# 读取图像
image_paths = glob.glob('Attachment_1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folders)

# %%
import cv2
import numpy as np
import glob
import os

# 创建文件夹以存储处理后的图像
output_folder = "output_images"
os.makedirs(output_folder, exist_ok=True)

# 创建不同处理阶段的文件夹
output_folders = {
    'apples': os.path.join(output_folder, 'apples'),
    'mask': os.path.join(output_folder, 'mask'),
    'GaussianBlur': os.path.join(output_folder, 'GaussianBlur'),
    'erode_dilate': os.path.join(output_folder, 'erode_dilate'),
    'draw_img': os.path.join(output_folder, 'draw_img')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

def process_image(image_path, output_folders):
    # 读取图像
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([20, 100, 150])
    upper_red2 = np.array([40, 255, 255])

    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((7, 7), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    # 寻找轮廓
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    # 绘制轮廓和边界框
    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # 以下是图像处理的代码...

    # 保存中间和最终图像
    image_name = os.path.splitext(os.path.basename(image_path))[0]

    # 保存苹果图像
    cv2.imwrite(os.path.join(output_folders['apples'], f"{image_name}_apples.jpg"), apples)

    # 保存掩膜图像
    cv2.imwrite(os.path.join(output_folders['mask'], f"{image_name}_mask.jpg"), mask)

    # 保存高斯模糊图像
    cv2.imwrite(os.path.join(output_folders['GaussianBlur'], f"{image_name}_GaussianBlur.jpg"), mask)

    # 保存腐蚀和膨胀图像
    cv2.imwrite(os.path.join(output_folders['erode_dilate'], f"{image_name}_erode_dilate.jpg"), mask)

    # 保存绘制轮廓后的图像
    cv2.imwrite(os.path.join(output_folders['draw_img'], f"{image_name}_draw_img.jpg"), draw_img)

    print(f"处理并保存完成：{image_name}")

# 读取图像
image_paths = glob.glob('Attachment_1/*.jpg')  # 修改为你的图像文件夹路径

# 处理每个图像
for image_path in image_paths:
    process_image(image_path, output_folders)

# %%
import random
import cv2
import numpy as np
import glob
from PIL import Image
import os

def is_point_inside_polygon(x, y, polygon):
    """
    判断点 (x, y) 是否在多边形内

    参数：
    x, y: 待判断的点的坐标
    polygon: 多边形的顶点坐标，以列表形式传递，例如 [(x1, y1), (x2, y2), ...]

    返回：
    如果点在多边形内，返回 True，否则返回 False
    """
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

# 蒙特卡洛算法计算面积
def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        # 判断点是否在多边形内
        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    # 估算多边形的面积
    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

# Specify the input and output directories
input_folder = '/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1'  # Change this to the path of your input images
output_folder = 'Answer to q4'  # Change this to the desired output path

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read image files from the input folder
image_paths = glob.glob(os.path.join(input_folder, '*.jpg'))



for image_path in image_paths:
    image = cv2.imread(image_path)

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)
    cv2.imshow("apples", apples)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    # lower_red1 = np.array([0, 100, 100])
    # upper_red1 = np.array([10, 255, 255])
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])
    # 青苹果
    # lower_red2 = np.array([20, 100, 150])
    # upper_red2 = np.array([40, 255, 255])


    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    # 青苹果开关
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    # Image.fromarray(mask).show()
    cv2.imshow("mask", mask)

    # 灰度
    # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # Image.fromarray(mask).show()

    # 高斯模糊
    mask = cv2.GaussianBlur(mask,(5,5),0)
    # Image.fromarray(mask).show()
    cv2.imshow("GaussianBlur", mask)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)
    # Image.fromarray(mask).show()
    cv2.imshow("erode & dilate", mask)

    # 寻找轮廓
    # contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    all_area_estimate = 0
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        img_1 = cv2.rectangle(draw_img, (x, y), (x + w, y + h), (0, 0, 255), 2)
        # 中心点 x+1/2*w，y+1/2*h
        # 蒙特卡洛算法计算面积
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
        # 累加求和
        all_area_estimate += area_estimate
    result_image_path = os.path.join(output_folder, os.path.basename(image_path))
    cv2.imwrite(result_image_path, draw_img)

    print("Processed:", image_path)

print("Image processing and contour detection completed for all images.")
# Out:
# Processed: /Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1/63.jpg
# Processed: /Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1/189.jpg
# Processed: /Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1/77.jpg
# Processed: /Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1/162.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zhangying/Library/Containers/com.tencent.xinWeChat/Data/Library/Application Support/com.tencent.xinWeChat/2.0b4.0.9/88ff490fe82b01f1143cc59c4d611b36/Message/MessageTemp/42fa9b97151f82e08d9e5f7286a71658/OpenData/Teacher.ipynb 单元格 9 line 1
# ...

# %% [markdown]
# 以上这串代码实现的是，对所有蒙特卡洛图像计算面积后的图像输出用于论文展示

# %% [markdown]
# 接下来要运行的是，将蒙特卡洛算出来的面积输出为一个excel表格，用于后续的质量计算，质量的计算不仅与像素有关，而且还和实际上的数量有关！！！

# %%
import random
import os
import cv2
import numpy as np
import glob
import pandas as pd

def is_point_inside_polygon(x, y, polygon):
    """
    判断点 (x, y) 是否在多边形内

    参数：
    x, y: 待判断的点的坐标
    polygon: 多边形的顶点坐标，以列表形式传递，例如 [(x1, y1), (x2, y2), ...]

    返回：
    如果点在多边形内，返回 True，否则返回 False
    """
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

# 蒙特卡洛算法计算面积
def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        # 判断点是否在多边形内
        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    # 估算多边形的面积
    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

# 读取图像文件夹
image_folder_path = '/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1'  # 修改为你的图像文件夹路径
output_excel_path = '蒙特卡洛面积.xlsx'  # 修改为你的输出 Excel 文件路径

image_paths = glob.glob(os.path.join(image_folder_path, '*.jpg'))

result_df = pd.DataFrame(columns=['序号', '面积'])

# 处理每张图像
for idx, image_path in enumerate(image_paths):
    image = cv2.imread(image_path)
    

    # 定义颜色阈值范围，这里是绿色的树叶
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # 将图像转换为HSV颜色空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # 根据颜色阈值创建树叶掩膜（mask）
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # 对掩膜进行形态学操作，以便更好地区分苹果和树叶
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)

    # 反转掩膜以去除树叶区域
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)
    cv2.imshow("apples", apples)

    # 转换到HSV颜色空间
    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    # 定义苹果颜色的范围
    # lower_red1 = np.array([0, 100, 100])
    # upper_red1 = np.array([10, 255, 255])
    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])
    # 青苹果
    # lower_red2 = np.array([20, 100, 150])
    # upper_red2 = np.array([40, 255, 255])


    # 根据颜色阈值创建苹果掩码
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    # 青苹果开关
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    # Image.fromarray(mask).show()
    cv2.imshow("mask", mask)

    # 灰度
    # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # Image.fromarray(mask).show()

    # 高斯模糊
    mask = cv2.GaussianBlur(mask,(5,5),0)
    # Image.fromarray(mask).show()
    cv2.imshow("GaussianBlur", mask)

    # 形态学操作改善掩码（先腐蚀后膨胀）
    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)
    # Image.fromarray(mask).show()
    cv2.imshow("erode & dilate", mask)

    # 寻找轮廓
    # contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    all_area_estimate = 0
    
for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
        all_area_estimate += area_estimate

result_df = result_df.append({'序号': idx + 1, '面积': all_area_estimate}, ignore_index=True)

result_df.to_excel(output_excel_path, index=False)
print("Results saved to:", output_excel_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bt/qcg_frss46xfvvsc6gdw2gd80000gn/T/ipykernel_6171/1736067350.py in ?()
#     133         x, y, w, h = cv2.boundingRect(cnt)
#     134         area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
#     135         all_area_estimate += area_estimate
#     136
# --> 137         result_df = result_df.append({'序号': idx + 1, '面积': all_area_estimate}, ignore_index=True)
#     138
#     139 result_df.to_excel(output_excel_path, index=False)
#     140 print("Results saved to:", output_excel_path)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# ...

# %%
#这个是仅仅打印的，看看能不能用吧
import random
import cv2
import numpy as np
import glob

def is_point_inside_polygon(x, y, polygon):
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

# 获取图像文件路径列表
image_folder_path = '/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1'  # 修改为你的图像文件夹路径
image_paths = glob.glob(image_folder_path + '/*.jpg')

for image_path in image_paths:
    image = cv2.imread(image_path)

    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])

    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    mask = cv2.GaussianBlur(mask, (5, 5), 0)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    all_area_estimate = 0
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
        all_area_estimate += area_estimate

    image_name = image_path.split('/')[-1].split('.')[0]
    print(f"图像 {image_name} 的苹果总面积估算值为：{all_area_estimate}")
# Out:
# 图像 63 的苹果总面积估算值为：8323.157
# 图像 189 的苹果总面积估算值为：0
# 图像 77 的苹果总面积估算值为：5758.554
# 图像 162 的苹果总面积估算值为：10601.559000000001
# 图像 176 的苹果总面积估算值为：19006.308
# 图像 88 的苹果总面积估算值为：6461.372
# 图像 200 的苹果总面积估算值为：0
# 图像 177 的苹果总面积估算值为：656.499
# 图像 89 的苹果总面积估算值为：5083.715999999999
# 图像 163 的苹果总面积估算值为：12872.392999999998
# 图像 188 的苹果总面积估算值为：64.07100000000001
# 图像 76 的苹果总面积估算值为：2981.516
# 图像 62 的苹果总面积估算值为：0
# 图像 74 的苹果总面积估算值为：4875.15
# 图像 60 的苹果总面积估算值为：6448.025
# 图像 48 的苹果总面积估算值为：0
# 图像 149 的苹果总面积估算值为：1128.818
# 图像 175 的苹果总面积估算值为：1960.167
# 图像 161 的苹果总面积估算值为：17730.782
# 图像 160 的苹果总面积估算值为：3372.193
# 图像 174 的苹果总面积估算值为：8657.408
# 图像 148 的苹果总面积估算值为：11169.331
# 图像 49 的苹果总面积估算值为：11007.271999999999
# 图像 61 的苹果总面积估算值为：9964.937000000002
# 图像 75 的苹果总面积估算值为：0
# 图像 59 的苹果总面积估算值为：8363.935
# 图像 71 的苹果总面积估算值为：5004.032999999999
# 图像 65 的苹果总面积估算值为：126.98399999999998
# 图像 170 的苹果总面积估算值为：5565.0419999999995
# 图像 164 的苹果总面积估算值为：400.88199999999995
# 图像 158 的苹果总面积估算值为：9460.797999999999
# 图像 159 的苹果总面积估算值为：1851.0520000000001
# ...

# %%
#现在试试用Excel
import random
import cv2
import numpy as np
import glob
import pandas as pd

def is_point_inside_polygon(x, y, polygon):
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

# 获取图像文件路径列表
image_folder_path = '/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1'  # 修改为你的图像文件夹路径
image_paths = glob.glob(image_folder_path + '/*.jpg')
# 创建一个空的列表，用于存储结果
result_list = []

for image_path in image_paths:
    image = cv2.imread(image_path)

    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])

    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    mask = cv2.GaussianBlur(mask, (5, 5), 0)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    all_area_estimate = 0
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
        all_area_estimate += area_estimate

    image_name = image_path.split('/')[-1].split('.')[0]
    num_of_apples = len(contours)
 # 将结果添加到列表中
    result_list.append({'Image': image_name,
                        'Number of Apples': num_of_apples,
                        'Total Area Estimate': all_area_estimate})

# 将列表转换为DataFrame
result_df = pd.DataFrame(result_list)

# 将DataFrame写入EXCEL文件
output_csv_path = '蒙特卡洛.xlsx'  # 修改为你的输 出EXCEL文件路径
result_df.to_excel(output_csv_path, index=False)

print(f"结果已写入EXCEL文件：{output_csv_path}")
# Out:
# 结果已写入EXCEL文件：蒙特卡洛.xlsx

# %%
import random
import os
import cv2
import numpy as np
import glob
import pandas as pd

def is_point_inside_polygon(x, y, polygon):
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

image_folder_path = '/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1'  # 修改为你的图像文件夹路径
output_excel_path = '蒙特卡洛.xlsx'  # 修改为你的输出 Excel 文件路径

image_paths = glob.glob(os.path.join(image_folder_path, '*.jpg'))

# 使用不同的变量名
result_df = pd.DataFrame(columns=['序号', '面积'])
for idx, image_path in enumerate(image_paths):
    image = cv2.imread(image_path)

    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    mask = cv2.GaussianBlur(mask, (5, 5), 0)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
     # 处理图像并计算面积
    all_area_estimate = 0
    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)

        # 蒙特卡洛算法计算面积
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)

        # 累加求和
        all_area_estimate += area_estimate

#   将结果添加到 DataFrame
    result_df = result_df.append({'序号': idx + 1, '面积': all_area_estimate}, ignore_index=True)

# 将结果保存到 Excel 文件
result_df.to_excel(output_excel_path, index=False)

print("Results saved to:", output_excel_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bt/qcg_frss46xfvvsc6gdw2gd80000gn/T/ipykernel_6171/2837956239.py in ?()
#      88         # 累加求和
#      89         all_area_estimate += area_estimate
#      90
#      91 #   将结果添加到 DataFrame
# ---> 92     result_df = result_df.append({'序号': idx + 1, '面积': all_area_estimate}, ignore_index=True)
#      93
#      94 # 将结果保存到 Excel 文件
#      95 result_df.to_excel(output_excel_path, index=False)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#希望是最后一次
import random
import cv2
import numpy as np
import glob
import pandas as pd
# 创建一个空的 DataFrame
result_df = pd.DataFrame(columns=['Image', 'Number of Apples', 'Total Area Estimate'])


# 在循环中逐行添加数据
result_df = result_df.append({'Image': image_name,
                              'Number of Apples': len(contours),
                              'Total Area Estimate': all_area_estimate},
                             ignore_index=True)

def is_point_inside_polygon(x, y, polygon):
    n = len(polygon)
    inside = False

    p1x, p1y = polygon[0][0]
    for i in range(n + 1):
        p2x, p2y = polygon[i % n][0]
        if y > min(p1y, p2y) and y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
                if p1x == p2x or x <= xinters:
                    inside = not inside
        p1x, p1y = p2x, p2y

    return inside

def monte_carlo_pi(num, polygon, x1, y1, x2, y2):
    points_inside_circle = 0

    for _ in range(num):
        x = random.uniform(x1, x2)
        y = random.uniform(y1, y2)

        if is_point_inside_polygon(x, y, polygon):
            points_inside_circle += 1

    w = abs(x1 - x2)
    h = abs(y1 - y2)
    pi_estimate = points_inside_circle / num * w * h
    return pi_estimate

# 获取图像文件路径列表
image_paths = glob.glob('/Users/zhangying/iCloud Drive (Archive) - 2/Desktop/Andrea/Academic 学术/建模资料/亚太地区A题解题/Attachment 1/*.jpg')  # 修改为你的图像文件夹路径

# 创建一个空的DataFrame，用于存储结果
result_df = pd.DataFrame(columns=['Image', 'Number of Apples', 'Total Area Estimate'])

for image_path in image_paths:
    image = cv2.imread(image_path)

    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    kernel = np.ones((5, 5), np.uint8)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_CLOSE, kernel)
    mask_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel)
    mask_apple = cv2.bitwise_not(mask_green)
    apples = cv2.bitwise_and(image, image, mask=mask_apple)

    hsv = cv2.cvtColor(apples, cv2.COLOR_BGR2HSV)

    lower_red1 = np.array([0, 100, 150])
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([160, 100, 100])
    upper_red2 = np.array([180, 255, 255])

    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)

    mask = cv2.GaussianBlur(mask, (5, 5), 0)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.erode(mask, kernel, iterations=2)
    mask = cv2.dilate(mask, kernel, iterations=2)

    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    draw_img = cv2.drawContours(image.copy(), contours, -1, (0, 255, 0), 3)
    all_area_estimate = 0

    for i in range(len(contours)):
        cnt = contours[i]
        x, y, w, h = cv2.boundingRect(cnt)
        area_estimate = monte_carlo_pi(1000, cnt, x, y, x+w, y+h)
        all_area_estimate += area_estimate

    image_name = image_path.split('/')[-1].split('.')[0]
    result_df = result_df.append({'Image': image_name,
                                  'Number of Apples': len(contours),
                                  'Total Area Estimate': all_area_estimate},
                                 ignore_index=True)

# 将DataFrame写入Excel文件
result_df.to_excel('蒙特卡洛.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/bt/qcg_frss46xfvvsc6gdw2gd80000gn/T/ipykernel_6171/2197443531.py in ?()
#       8 result_df = pd.DataFrame(columns=['Image', 'Number of Apples', 'Total Area Estimate'])
#       9
#      10
#      11 # 在循环中逐行添加数据
# ---> 12 result_df = result_df.append({'Image': image_name,
#      13                               'Number of Apples': len(contours),
#      14                               'Total Area Estimate': all_area_estimate},
#      15                              ignore_index=True)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# ...

# %%
import pandas as pd
